# %% [markdown]
# This exercise has been done with the help of videos on Knowledge Shelf YouTube Channel.

# %% [markdown]
# iloc basically means index location.

# %%
import pandas as pd

# %%
bond = pd.read_csv("JB007.csv")

# %% [markdown]
# Below mentioned two commands i.e. bond.loc[15] and bond.iloc[15] will give same output at this point.

# %%
bond.loc[15]
# Out:
# Film                              Licence to Kill
# Year                                         1989
# Years lapse                                     2
# Bond actor                         Timothy Dalton
# Bond actor appearance                           2
# Villians Dispatched                            10
# Others' Dispatched                             13
# Total Dispatched                               23
# Adjusted box office                         250.9
# Actual box office                           156.2
# Adjusted budget                              56.7
# Actual budget                                  36
# Director                                John Glen
# Rotten Tomatoes critic score                  76%
# Rotten Tomatoes audience score                59%
# Golden Globe nominations                        0
# Golden Globe wins                               0
# Academy Award nominations                       0
# Academy Award wins                              0
# ...

# %%
bond.iloc[15]
# Out:
# Film                              Licence to Kill
# Year                                         1989
# Years lapse                                     2
# Bond actor                         Timothy Dalton
# Bond actor appearance                           2
# Villians Dispatched                            10
# Others' Dispatched                             13
# Total Dispatched                               23
# Adjusted box office                         250.9
# Actual box office                           156.2
# Adjusted budget                              56.7
# Actual budget                                  36
# Director                                John Glen
# Rotten Tomatoes critic score                  76%
# Rotten Tomatoes audience score                59%
# Golden Globe nominations                        0
# Golden Globe wins                               0
# Academy Award nominations                       0
# Academy Award wins                              0
# ...

# %%
bond.iloc[[15,20]] # this wwill output data of row 15 and 20.
# Out:
#                Film  Year  Years lapse      Bond actor  Bond actor appearance  \
# 15  Licence to Kill  1989          2.0  Timothy Dalton                      2
# 20    Casino Royale  2006          4.0    Daniel Craig                      1
#
#     Villians Dispatched  Others' Dispatched  Total Dispatched  \
# 15                   10                  13                23
# 20                   11                  11                22
#
#     Adjusted box office  Actual box office  ...  Golden Globe wins  \
# 15                250.9              156.2  ...                  0
# 20                581.5              594.2  ...                  0
#
#     Academy Award nominations Academy Award wins Number of Bond drinks  \
# 15                          0                  0                   4.0
# 20                          0                  0                  26.0
#
#    Bond girls  Bond car make  Runtime minutes  Month released  Rating  \
# ...

# %%
bond.iloc[:4] # this will output data from row 0 to 3.
# Out:
#                     Film  Year  Years lapse    Bond actor  \
# 0                 Dr. No  1962          NaN  Sean Connery
# 1  From Russia With Love  1963          1.0  Sean Connery
# 2             Goldfinger  1964          1.0  Sean Connery
# 3            Thunderball  1965          1.0  Sean Connery
#
#    Bond actor appearance  Villians Dispatched  Others' Dispatched  \
# 0                      1                    4                   8
# 1                      2                   11                  16
# 2                      3                    9                  68
# 3                      4                   20                  90
#
#    Total Dispatched  Adjusted box office  Actual box office  ...  \
# 0                12                448.8               59.5  ...
# 1                27                543.8               78.9  ...
# 2                77                820.4              124.9  ...
# 3               110                848.1              141.2  ...
#
# ...

# %%
bond.iloc[4:8] # this will output data from row 4 to 7.
# Out:
#                               Film  Year  Years lapse      Bond actor  \
# 4              You Only Live Twice  1967          2.0    Sean Connery
# 5  On Her Majesty's Secret Service  1969          2.0  George Lazenby
# 6             Diamonds Are Forever  1971          2.0    Sean Connery
# 7                 Live and Let Die  1973          2.0     Roger Moore
#
#    Bond actor appearance  Villians Dispatched  Others' Dispatched  \
# 4                      5                   21                 175
# 5                      1                    5                  37
# 6                      6                    7                  42
# 7                      1                    8                   5
#
#    Total Dispatched  Adjusted box office  Actual box office  ...  \
# 4               196                514.2              101.0  ...
# 5                42                291.5               64.6  ...
# 6                49                442.5              116.0  ...
# ...

# %%
bond.iloc[20:] # it will print from 20th row till last row.
# Out:
#                  Film  Year  Years lapse    Bond actor  Bond actor appearance  \
# 20      Casino Royale  2006          4.0  Daniel Craig                      1
# 21  Quantum of Solace  2008          2.0  Daniel Craig                      2
# 22            Skyfall  2012          4.0  Daniel Craig                      3
#
#     Villians Dispatched  Others' Dispatched  Total Dispatched  \
# 20                   11                  11                22
# 21                   16                  15                31
# 22                   26                  23                49
#
#     Adjusted box office  Actual box office  ...  Golden Globe wins  \
# 20                581.5              594.2  ...                  0
# 21                514.2              576.0  ...                  0
# 22                879.8             1108.6  ...                  1
#
#     Academy Award nominations Academy Award wins Number of Bond drinks  \
# ...

# %%
bond.iloc[0:21:2] # it will print 0 to 20th row skipping 1 row in between each time.
# Out:
#                            Film  Year  Years lapse      Bond actor  \
# 0                        Dr. No  1962          NaN    Sean Connery
# 2                    Goldfinger  1964          1.0    Sean Connery
# 4           You Only Live Twice  1967          2.0    Sean Connery
# 6          Diamonds Are Forever  1971          2.0    Sean Connery
# 8   The Man with the Golden Gun  1974          1.0     Roger Moore
# 10                    Moonraker  1979          2.0     Roger Moore
# 12                    Octopussy  1983          2.0     Roger Moore
# 14         The Living Daylights  1987          2.0  Timothy Dalton
# 16                    GoldenEye  1995          6.0  Pierce Brosnan
# 18      The World is Not Enough  1999          2.0  Pierce Brosnan
# 20                Casino Royale  2006          4.0    Daniel Craig
#
#     Bond actor appearance  Villians Dispatched  Others' Dispatched  \
# 0                       1                    4                   8
# ...

# %%
bond = pd.read_csv("JB007.csv", index_col="Film")

# %%
bond.sort_index()
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# A View to a Kill                 1985          2.0     Roger Moore
# Casino Royale                    2006          4.0    Daniel Craig
# Diamonds Are Forever             1971          2.0    Sean Connery
# Die Another Day                  2002          3.0  Pierce Brosnan
# Dr. No                           1962          NaN    Sean Connery
# For Your Eyes Only               1981          2.0     Roger Moore
# From Russia With Love            1963          1.0    Sean Connery
# GoldenEye                        1995          6.0  Pierce Brosnan
# Goldfinger                       1964          1.0    Sean Connery
# Licence to Kill                  1989          2.0  Timothy Dalton
# Live and Let Die                 1973          2.0     Roger Moore
# Moonraker                        1979          2.0     Roger Moore
# Octopussy                        1983          2.0     Roger Moore
# ...

# %%
bond.iloc[0] # Despite of index being set to "Film", it will work.
# Out:
# Year                                       1962
# Years lapse                                 NaN
# Bond actor                         Sean Connery
# Bond actor appearance                         1
# Villians Dispatched                           4
# Others' Dispatched                            8
# Total Dispatched                             12
# Adjusted box office                       448.8
# Actual box office                          59.5
# Adjusted budget                               7
# Actual budget                               1.1
# Director                          Terence Young
# Rotten Tomatoes critic score                96%
# Rotten Tomatoes audience score              82%
# Golden Globe nominations                      1
# Golden Globe wins                             1
# Academy Award nominations                     0
# Academy Award wins                            0
# Number of Bond drinks                      11.5
# Bond girls                                    3
# ...

# %%
bond.iloc[15] # it will display data of 15th row in dataset.
# Out:
# Year                                        1989
# Years lapse                                    2
# Bond actor                        Timothy Dalton
# Bond actor appearance                          2
# Villians Dispatched                           10
# Others' Dispatched                            13
# Total Dispatched                              23
# Adjusted box office                        250.9
# Actual box office                          156.2
# Adjusted budget                             56.7
# Actual budget                                 36
# Director                               John Glen
# Rotten Tomatoes critic score                 76%
# Rotten Tomatoes audience score               59%
# Golden Globe nominations                       0
# Golden Globe wins                              0
# Academy Award nominations                      0
# Academy Award wins                             0
# Number of Bond drinks                          4
# ...

# %%
bond.iloc[18:] # it will display from 18th row till last.
# Out:
#                          Year  Years lapse      Bond actor  \
# Film
# The World is Not Enough  1999          2.0  Pierce Brosnan
# Die Another Day          2002          3.0  Pierce Brosnan
# Casino Royale            2006          4.0    Daniel Craig
# Quantum of Solace        2008          2.0    Daniel Craig
# Skyfall                  2012          4.0    Daniel Craig
#
#                          Bond actor appearance  Villians Dispatched  \
# Film
# The World is Not Enough                      3                   27
# Die Another Day                              4                   31
# Casino Royale                                1                   11
# Quantum of Solace                            2                   16
# Skyfall                                      3                   26
#
#                          Others' Dispatched  Total Dispatched  \
# Film
# The World is Not Enough                  43                70
# ...

# %%
bond.iloc[:5] # It will diaplay from 0th to 4th row.
# Out:
#                        Year  Years lapse    Bond actor  Bond actor appearance  \
# Film
# Dr. No                 1962          NaN  Sean Connery                      1
# From Russia With Love  1963          1.0  Sean Connery                      2
# Goldfinger             1964          1.0  Sean Connery                      3
# Thunderball            1965          1.0  Sean Connery                      4
# You Only Live Twice    1967          2.0  Sean Connery                      5
#
#                        Villians Dispatched  Others' Dispatched  \
# Film
# Dr. No                                   4                   8
# From Russia With Love                   11                  16
# Goldfinger                               9                  68
# Thunderball                             20                  90
# You Only Live Twice                     21                 175
#
#                        Total Dispatched  Adjusted box office  \
# Film
# ...

# %%
bond.iloc[[5,10,15,20]] # it will display data of row numbers mentioned in list i.e. 5, 10, 15 and 20.
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# On Her Majesty's Secret Service  1969          2.0  George Lazenby
# Moonraker                        1979          2.0     Roger Moore
# Licence to Kill                  1989          2.0  Timothy Dalton
# Casino Royale                    2006          4.0    Daniel Craig
#
#                                  Bond actor appearance  Villians Dispatched  \
# Film
# On Her Majesty's Secret Service                      1                    5
# Moonraker                                            4                   12
# Licence to Kill                                      2                   10
# Casino Royale                                        1                   11
#
#                                  Others' Dispatched  Total Dispatched  \
# Film
# On Her Majesty's Secret Service                  37                42
# Moonraker                                        69                81
# ...
