# %% [markdown]
# This exercise has been done with the help of videos on Knowledge Shelf YouTube Channel.

# %%
import pandas as pd

# %%
bond = pd.read_csv("JB007.csv", index_col="Film")

# %%
bond.head()
# Out:
#                        Year  Years lapse    Bond actor  Bond actor appearance  \
# Film
# Dr. No                 1962          NaN  Sean Connery                      1
# From Russia With Love  1963          1.0  Sean Connery                      2
# Goldfinger             1964          1.0  Sean Connery                      3
# Thunderball            1965          1.0  Sean Connery                      4
# You Only Live Twice    1967          2.0  Sean Connery                      5
#
#                        Villians Dispatched  Others' Dispatched  \
# Film
# Dr. No                                   4                   8
# From Russia With Love                   11                  16
# Goldfinger                               9                  68
# Thunderball                             20                  90
# You Only Live Twice                     21                 175
#
#                        Total Dispatched  Adjusted box office  \
# Film
# ...

# %% [markdown]
# loc stands for location.

# %%
bond.sort_index(inplace=True)
# It will alphabetically sort the table based on index column "Film".

# %%
bond.head()
# Out:
#                       Year  Years lapse      Bond actor  \
# Film
# A View to a Kill      1985          2.0     Roger Moore
# Casino Royale         2006          4.0    Daniel Craig
# Diamonds Are Forever  1971          2.0    Sean Connery
# Die Another Day       2002          3.0  Pierce Brosnan
# Dr. No                1962          NaN    Sean Connery
#
#                       Bond actor appearance  Villians Dispatched  \
# Film
# A View to a Kill                          7                    5
# Casino Royale                             1                   11
# Diamonds Are Forever                      6                    7
# Die Another Day                           4                   31
# Dr. No                                    1                    4
#
#                       Others' Dispatched  Total Dispatched  \
# Film
# A View to a Kill                      57                62
# Casino Royale                         11                22
# ...

# %%
bond.loc["Die Another Day"]
# Out:
# Year                                        2002
# Years lapse                                    3
# Bond actor                        Pierce Brosnan
# Bond actor appearance                          4
# Villians Dispatched                           31
# Others' Dispatched                            20
# Total Dispatched                              51
# Adjusted box office                        465.4
# Actual box office                          431.9
# Adjusted budget                            154.2
# Actual budget                                142
# Director                            Lee Tamahori
# Rotten Tomatoes critic score                 57%
# Rotten Tomatoes audience score               41%
# Golden Globe nominations                       1
# Golden Globe wins                              0
# Academy Award nominations                      0
# Academy Award wins                             0
# Number of Bond drinks                        5.5
# ...

# %%
bond.loc["Casino Royale"]
# Out:
# Year                                         2006
# Years lapse                                     4
# Bond actor                           Daniel Craig
# Bond actor appearance                           1
# Villians Dispatched                            11
# Others' Dispatched                             11
# Total Dispatched                               22
# Adjusted box office                         581.5
# Actual box office                           594.2
# Adjusted budget                             145.3
# Actual budget                                 150
# Director                          Martin Campbell
# Rotten Tomatoes critic score                  95%
# Rotten Tomatoes audience score                89%
# Golden Globe nominations                        0
# Golden Globe wins                               0
# Academy Award nominations                       0
# Academy Award wins                              0
# Number of Bond drinks                          26
# ...

# %%
bond.loc["Diamonds Are Forever":"Moonraker"]
# Out:
#                        Year  Years lapse      Bond actor  \
# Film
# Diamonds Are Forever   1971          2.0    Sean Connery
# Die Another Day        2002          3.0  Pierce Brosnan
# Dr. No                 1962          NaN    Sean Connery
# For Your Eyes Only     1981          2.0     Roger Moore
# From Russia With Love  1963          1.0    Sean Connery
# GoldenEye              1995          6.0  Pierce Brosnan
# Goldfinger             1964          1.0    Sean Connery
# Licence to Kill        1989          2.0  Timothy Dalton
# Live and Let Die       1973          2.0     Roger Moore
# Moonraker              1979          2.0     Roger Moore
#
#                        Bond actor appearance  Villians Dispatched  \
# Film
# Diamonds Are Forever                       6                    7
# Die Another Day                            4                   31
# Dr. No                                     1                    4
# ...

# %%
bond.loc["Dr. No":] # from "Dr. No" till last row of the table will be diaplayed.
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# Dr. No                           1962          NaN    Sean Connery
# For Your Eyes Only               1981          2.0     Roger Moore
# From Russia With Love            1963          1.0    Sean Connery
# GoldenEye                        1995          6.0  Pierce Brosnan
# Goldfinger                       1964          1.0    Sean Connery
# Licence to Kill                  1989          2.0  Timothy Dalton
# Live and Let Die                 1973          2.0     Roger Moore
# Moonraker                        1979          2.0     Roger Moore
# Octopussy                        1983          2.0     Roger Moore
# On Her Majesty's Secret Service  1969          2.0  George Lazenby
# Quantum of Solace                2008          2.0    Daniel Craig
# Skyfall                          2012          4.0    Daniel Craig
# The Living Daylights             1987          2.0  Timothy Dalton
# ...

# %%
bond.loc[:"On Her Majesty's Secret Serices"] 
# It will diaplay from beginning of the table to "On Her Majesty's Secret Services"
# Out:
#                        Year  Years lapse      Bond actor  \
# Film
# A View to a Kill       1985          2.0     Roger Moore
# Casino Royale          2006          4.0    Daniel Craig
# Diamonds Are Forever   1971          2.0    Sean Connery
# Die Another Day        2002          3.0  Pierce Brosnan
# Dr. No                 1962          NaN    Sean Connery
# For Your Eyes Only     1981          2.0     Roger Moore
# From Russia With Love  1963          1.0    Sean Connery
# GoldenEye              1995          6.0  Pierce Brosnan
# Goldfinger             1964          1.0    Sean Connery
# Licence to Kill        1989          2.0  Timothy Dalton
# Live and Let Die       1973          2.0     Roger Moore
# Moonraker              1979          2.0     Roger Moore
# Octopussy              1983          2.0     Roger Moore
#
#                        Bond actor appearance  Villians Dispatched  \
# Film
# A View to a Kill                           7                    5
# ...

# %%
bond.loc[["Live and Let Die", "Licence to Kill"]]
# it will display these two rows only.
# Out:
#                   Year  Years lapse      Bond actor  Bond actor appearance  \
# Film
# Live and Let Die  1973          2.0     Roger Moore                      1
# Licence to Kill   1989          2.0  Timothy Dalton                      2
#
#                   Villians Dispatched  Others' Dispatched  Total Dispatched  \
# Film
# Live and Let Die                    8                   5                13
# Licence to Kill                    10                  13                23
#
#                   Adjusted box office  Actual box office  Adjusted budget  \
# Film
# Live and Let Die                460.3              126.4             30.8
# Licence to Kill                 250.9              156.2             56.7
#
#                   ...  Golden Globe wins Academy Award nominations  \
# Film              ...
# Live and Let Die  ...                  0                         1
# Licence to Kill   ...                  0                         0
#
# ...

# %%
bond.loc[["Gold Bond", "Octopussy", "Moonraker"]]
# "Gold Bond" being no such movie, all data in that row will be NaN.
# Out:
# C:\Users\CA DHEERAJ\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#              Year  Years lapse   Bond actor  Bond actor appearance  \
# Film
# Gold Bond     NaN          NaN          NaN                    NaN
# Octopussy  1983.0          2.0  Roger Moore                    6.0
# Moonraker  1979.0          2.0  Roger Moore                    4.0
#
#            Villians Dispatched  Others' Dispatched  Total Dispatched  \
# Film
# Gold Bond                  NaN                 NaN               NaN
# Octopussy                 15.0                43.0              58.0
# Moonraker                 12.0                69.0              81.0
#
# ...

# %%
"Gold Bond" in bond.index
# Out:
# False

# %% [markdown]
# Here output False means "Gold Bond" doesn't exist in dataset.
